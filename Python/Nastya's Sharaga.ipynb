# %%
#Lesson_1
#Практическая 1.1
print("ФИ: Абакумова Анастасия")
print("4. Экспериментирую эксперименты")
#Практическая 1.2
#1
var_int, var_float, var_str = 10, 8.4, "No"
#2
var_big = var_int * 3.5
#3
var_float -= 1
#4
var_int / var_float
var_big / var_float
#5
var_str += "No" + "Yes" * 3
#6
print(var_int, var_float, var_str, var_big, sep=', ')
#7
print(float(input()) + float(input()) + float(input()))
#8
print(int(input()) * int(input()) / 2)

# %%
#Lesson_2
#Практическая_1
#1 user.py
name = input("What is your name? ")
age = input("How old are you? ")
adress = input("Where are you live? ")
print(f"This is {name}", f"It is {age}", f"She live in {adress}", sep='\n')
#2 arithmetic.py
answer = input("Try to solve this: 4 * 100 - 54 = ?")
print("Correct answer is 346.", f"Your answer is {answer}.", sep='\n')
#3
num1, num2, num3, num4 = input(), input(), input(), input()
result = (float(num1) + float(num2)) / (float(num3) + float(num4))
print(round(result, 2))
#4
n, k = int(input()), int(input())
print(f"Школьникам: {k // n}", f"В корзине: {k % n}", sep='\n')
#5
n = int(input())
print(f"{(n // 60) % 24}:{n % 60}") #ЧЧ:ММ
#6
name = input("Enter your name: ")
print(f"Hello, {name}!")
#Практическая_2
#1
a, b = 2, 3
#2
a != b and a + b == 5 #True
a == b and a != b #False
#3
a == b or a != b #True
a == b or a + b == 6 #False
#4
str(a) == '2' #True
b == int('3') #True
#5
print(float(input()) > float(input()))
#6
print(min(int(input()), int(input())))
#7
x = int(input())
if x > 0:
    print(1)
elif x < 0:
    print(-1)
else:
    print(0)
#8
year = int(input())
if year % 4 == 0 and (year % 100 != 0 or year % 400 == 0):
    print("YES")
else:
    print("NO")
#9
print(min(int(input()), int(input()), int(input())))
#10
a, b, c = int(input()), int(input()), int(input())
if a == b == c:
    print(3)
elif a == b or b == c:
    print(2)
else:
    print(0)
#11 TakeInput.py
text = input("Type something: ")
if len(text) != 0:
    print("OK")
#12 PosNeg.py
if float(input()) > 0:
    print(1)
else:
    print(-1)
# Out:
# -10
# -1

# %%
#Lesson_3
#Практическая_1
a, b = input(), input()
if a.isnumeric() and b.isnumeric():
    print(float(a) + float(b))
else:
    print(a + b)
#Практическая_2
#1,2
try:
    old = int(input('Ваш возраст: '))
    print('Рекомендовано:', end=' ')
    if 3 <= old < 6:
        print('"Заяц в лабиринте"')
    elif 6 <= old < 12:
        print('"Марсианин"')
    elif 12 <= old < 16:
        print('"Загадочный остров"')
    elif 16 <= old:
        print('"Поток сознания"')
    else:
        print('Покинуть коляску')
except ValueError:
    print("Введите целое число.")
#3
a = float(input())
if a == 0:
    print(0)
else:
    print(int(a / abs(a)))
#4
x1, y1, x2, y2 = int(input()), int(input()), int(input()), int(input())
print("YES" if (x1 - x2 + y1 - y2) % 2 == 0 else "NO")
#5
x1, y1, x2, y2 = int(input()), int(input()), int(input()), int(input())
print("YES" if x1 == x2 or y1 == y2 else "NO")
#6
x1, y1, x2, y2 = int(input()), int(input()), int(input()), int(input())
print("YES" if abs(x1 - x2) <= 1 and abs(y1 - y2) <= 1 else "NO")
#7
x1, y1, x2, y2 = int(input()), int(input()), int(input()), int(input())
print("YES" if abs(x1 - x2) == abs(y1 - y2) else "NO")
#8
x1, y1, x2, y2 = int(input()), int(input()), int(input()), int(input())
print("YES" if abs(x1 - x2) == abs(y1 - y2) or x1 == x2 or y1 == y2 else "NO")
#9
x1, y1, x2, y2 = int(input()), int(input()), int(input()), int(input())
cond = (abs(x1 - x2) == 2 and abs(y1 - y2) == 1) or (abs(x1 - x2) == 1 and abs(y1 - y2) == 2)
print("YES" if cond else "NO")
#10
n, m, k = int(input()), int(input()), int(input())
print("YES" if n % k == 0 or m % k == 0 else "NO")
# Out:
# 1
# 1
# 7
# 8
# NO

# %%
#Lesson_4
#Практическая_1
#1
total = 100
while total > 0:
    n = int(input())
    if total > n:
        total -= n
    else:
        print("Недопустимая операция")
        break
print("Ресурс исчерпан")
#2
counter = 0
while counter <= 20:
    print(2 ** counter)
    counter += 1
#3
n, counter = int(input()), 1
while counter ** 2 < n:
    print(counter ** 2)
    counter += 1
#4
n, counter = int(input()), 2
while n % counter != 0:
    counter += 1
print(counter)
#5
from math import log2
n, counter = int(input()), 1
while counter < n:
    counter *= 2
print(int(log2(counter) - 1), int(counter / 2))
#6
x, p, y = float(input()), float(input()), float(input())
counter = 0
while x < y:
    x *= 1 + p / 100
    x = round(x, 2)
    counter += 1
print(counter)
#Практическая_2
#1  
def negative():
    print("Отрицательное")

def positive():
    print("Положительное")

def test():
    n = int(input())
    if n > 0:
        positive()
    elif n < 0:
        negative()

test()
#2
def distance(x1, y1, x2, y2):
    return ((x1 - x2) ** 2 + (y1 - y2) ** 2) ** 0.5

x1, y1, x2, y2 = float(input()), float(input()), float(input()), float(input())
print(distance(x1, y1, x2, y2))
#3
def power(a, n):
    result = a
    while n > 1:
        result *= a
        n -= 1
    return result

a, n = float(input()), int(input())
print(power(a, n))
#4
def power(a, n):
    return a if n == 1 else a * power(a, n - 1)
    
a, n = float(input()), int(input())
print(power(a, n))
#5
def capitalize(s):
    result = ''
    for word in s.split():
        result += f"{word[0].upper()}{word[1:]} "
    return result[:-1]

print(capitalize(input()))
# Out:
# many words should be big
# Many Words Should Be Big

# %%
#Lesson_5
#Практическая_1
from math import pi

def cylinder(r, h):
    def circle(r):
        return pi * (r ** 2)
    
    square = round(2 * pi * r * h, 2)
    flag = int(input("Напишите:\n0 - вывести боковую площадь цилиндра\
                       \n1 - вывести полную площадь цилиндра\n> "))
    if flag:
        square += round(2 * circle(r), 2)
    return square

r = float(input("Введите радиус цилиндра: "))
h = float(input("Введите высоту цилиндра: "))
print(cylinder(r, h))
#Практическая_2
#1
def two_str_concat(s1, s2):
    return s1 + s2
print(two_str_concat(input(), input()))
#2
def no_zero_mul():
    result = 1
    while True:
        temp = float(input())
        if temp == 0:
            break
        result *= temp
    return result
print(no_zero_mul())
#Практическая_3
def getInput():
    return input()
def testInput(x):
    return x.isnumeric()
def strToInt(s):
    return int(s)
def printInt(i):
    print(i)
inp = getInput()
if testInput(inp):
    printInt(strToInt(inp))
# Out:
# abs5

# %%
#Lesson_6
#Практическая_1
#1
while True:
    num = int(input("Write an integer number: "))
    if num == 0:
        break
    print(chr(num))
#2
s = input()
if len(s) > 10:
    print("Warning! Your string is so big!")
else:
    print(s + '*' * (10 - len(s)))
#3
temp = int(input())
mi, ma, i = temp, temp, 0
while i < 5:
    temp = int(input())
    ma = temp if temp > ma else ma
    mi = temp if temp < mi else mi
    i += 1
print(round(mi, 2), round(ma, 2))
#Практическая_2
from math import pi, pow

def rectangle(a, b):
    return round(a * b, 2)
def triangle(a, h):
    return round(0.5 * a * h, 2)
def circle(r):
    return round(pi * pow(r, 2), 2)
# Out:
# 5
# 6
# 1
# 3
# 8
# 10
# 1 10

# %%
#Lesson_7
#Практическая_1
#1
from random import randint
n, l = int(input("Type integer as list length: ")), []
for _ in range(n):
    l.append(randint(-256, 255))
#print(f"Generated list with numbers in range [-256, 255]:\n{l}")
#2
l = list(range(0, 100, 17))
#print(l)
#3
#l = list(range(-55, 432, 6))
counter = 0
for el in l:
    if el < 0:
        counter += 1
print(counter)
#4
words, lengths = [], []
for _ in range(5):
    words.append(input())
    lengths.append(len(words[-1]))
print(words, lengths)
#5
a, b = int(input()), int(input())
print(*range(a, b+1))
#6
a, b = int(input()), int(input())
print(*range(a, b+1) if a < b else range(a, b-1, -1))
#7
a, b = int(input()), int(input())
a += a % 2 - 1 #если чет, то уменьшаем на 1
print(*range(a, b-1, -2))
#8
result = 0
for _ in range(10):
    result += int(input())
print(result)
#9
result = 0
for _ in range(int(input())):
    result += int(input())
print(result)
#Можно и за 0 переменных, если сделать IQ += 1:
print(sum([int(input()) for _ in range(int(input()))]))
#10
n = int(input())
result = sum(range(1, n+1))
for _ in range(n-1):
    result -= int(input())
print(result)
#Практическая_2
#1
s = input()
l, u = 0, 0
for symb in s:
    if symb.isupper():
        u += 1
    else:
        l += 1
print(s.upper() if u > l else s.lower())
#2
nums = []
while len(nums) != 2:
    n = input()
    if n.isdigit():
        nums.append(int(n))
print(sum(nums))
#3
s = input()
print(s.count(' ') + 1)
#4
s = input()
space = s.find(' ')
s = s[space+1:] + ' ' + s[:space]
print(s)
#5
s = input()
mid = len(s) // 2
if len(s) % 2 == 1:
    mid += 1
result = s[mid:] + s[:mid]
print(result)
#6
s = input()
f, l = s.find('h'), s[::-1].find('h')
print(s[:f] + s[-l:])
#7
s = 'H@@@ello @@@ @@abb@@'
s = s.replace('@', '')
#print(s)
# Out:
# Hello  abb

# %%
#Lesson_8
#Практическая_1
#1
import random as rnd
print(rnd.randrange(6, 12, 2))
print(rnd.randrange(5, 100, 5))
#2
a, b = int(input("Type 2 numbers:\n")), int(input())
num = rnd.random() * (b - a) + a
if input("Type 'i' or 'd': ") == 'i':
    print(round(num))
else:
    print(num)
#3
import time
def randomizer():
    print('Welcome to "Cuckoo randomizer!"\nI can predict the time of your lifespan left.')
    time.sleep(1)
    print('Let\'s look at your fortune.', end='')
    for _ in range(10):
        time.sleep(0.5)
        print('.', end='')
    print('\n')
    print(f'Cuckoo thinks that you have at least {rnd.randrange(10, 50)} years!')
    print('You can sleep calmly this time.')
#4 here we go again
def fib(n):
    if n == 0 or n == 1:
        return n
    else:
        return fib(n-1) + fib(n-2)
#5
def foo():
    n = int(input())
    if n != 0:
        print(foo())
    return n
print(foo())
#6
#l = [[population, square]...] а можно понятней входные данные?
result = 0
for el in l:
    result += el[0]/el[1]
print(result/12)
#Практическая_2
#1
nums = []
for _ in range(8):
    nums.append(float(input()))
print(sum(nums), max(nums), min(nums))
#2
def print_list(l):
    for i in range(10):
        print(*l[i:i+10], sep=' ', end='\n')

l = []
for _ in range(100):
    l.append(round(rnd.random(), 2))
print("Not sorted list:")
print_list(l)
l.sort()
print("Sorted list:")
print_list(l)
#3
#l = [some_data]
print(*l[::2])
#4
#l = [some_data_again]
for el in l:
    if el % 2 == 0:
        print(el, end=' ')

#5
#l = [some_data_again_and_again]
for i in range(1, len(l)):
    if l[i] > l[i-1]:
        print(l[i], end=' ')
#6
#l = [and_again]
for i in range(1, len(l)):
    if (l[i] > 0 and l[i-1] > 0) or (l[i] < 0 and l[i-1] < 0):
        print(l[i-1], l[i])
        break
#7
heights = map(int, input().split())
height = int(input())
for i, val in enumerate(heights):
    if height > val:
        print(i+1)
        break
#8
from math import comb
#l = [data_again]
s = [] #set, ha-ha
result = 0
for el in l:
    if el not in s:
        s.append(el)
        result += comb(l.count(el), 2) #C(n, 2)
print(result)
#9
#l = [some_data], k
l.pop(k)
# Out:
# 11

# %%
#Lesson_9
#Практическая_1
#1
a = [1, 2, 3]
b = a[:]
c = a.copy()
b.append(4)
c.append(5)
print(a, b, c)
#2
from random import randint
def nums():
    a, b = [], []
    for _ in range(10):
        a.append(randint(0, 5))
        b.append(randint(-5, 0))
    return tuple(a), tuple(b)
a, b = nums()
c = a + b
print(c, c.count(0), sep='\n')
#Практическая_2
#1
school = {'1а': 27, '3б': 23, '7в': 25, '11а': 24}
school['7в'] -= 2 #а)
school['4а'] = 21
school.pop('3б')
print(sum(school.values()))
#2
def rev_dict(d):
    result = {}
    for key, value in d:
        result[value] = key
    return result

n = {1: 's1', 2: 's2', 3: 's3', 4: 's4', 5: 's5'}
print(rev_dict(n.items()))
# Out:
# {'s1': 1, 's2': 2, 's3': 3, 's4': 4, 's5': 5}

# %%
#Lesson_10
#Практическая
#1
nums = ["один", "два", "три", "четыре", "пять"]
with open('data.txt') as inp, open('dataRu.txt', 'w') as outp:
    for i, line in enumerate(inp.readlines()):
        line = [nums[i]] + line.split()[1:]
        outp.write(' '.join(line) + '\n')
#2
with open('nums.txt') as inp:
    print(sum(map(int, inp.readline().strip().split())))
# Out:
# 2304

# %%
#Lesson_11
#!pip install --upgrade pip
#!pip install lxml
#!pip install requests
#!pip install beautifulsoup4
#Практическая
#1
import requests
from bs4 import BeautifulSoup

url = 'https://www.pleer.ru'
response = requests.get(url)
print(response.status_code) #204 == no content
#Сайт не работает с get-запросами, делайте новую лабу
#2
import requests
import json
from bs4 import BeautifulSoup

url = 'https://www.blockchain.com/ru/btc/blocks'
response = requests.get(url)
response.json()
#И снова ошибка, no json for you, делайте новую лабу
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/Desktop/Courses/Algorithms/Python/lib/python3.10/site-packages/requests/models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File /usr/lib/python3.10/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# ...

# %%
#Lesson_12
#!pip install pytelegrambotapi
import telebot
from telebot import types
import requests
import re
token = '5986356872:AAGF2e6o5CQzyW2hKUYd8NWclzQU5TEOd6w'
bot = telebot.TeleBot(token)

@bot.message_handler(commands=['start'])
def welcome(message):
    stick = 'CAACAgIAAxkBAAMUY-6nZbQGkDyELBKMOVZgnIlQQcQAAgMAA7IhXxXWMP3hcRRZQi4E'
    bot.send_sticker(message.chat.id, stick)
    
    welc_message = 'Привет! Я бот с описаниями персонажей из игры League of Legends.\n'
    bot.send_message(message.chat.id, welc_message)
    
    #keyboard
    markup = types.InlineKeyboardMarkup(row_width=1)
    first = types.InlineKeyboardButton(text='Люкс', callback_data='Lux')
    second = types.InlineKeyboardButton(text='Гарен', callback_data='Garen')
    third = types.InlineKeyboardButton(text='Мастер Йи', callback_data='MasterYi')
    markup.add(first, second, third)
    choice_message = 'Выбери персонажа, чтобы узнать о нем побольше.'
    bot.send_message(message.chat.id, choice_message, reply_markup=markup)
    
@bot.callback_query_handler(func=lambda callback: callback.data)
def check_callback_data(callback):
    link = f'https://ddragon.leagueoflegends.com/cdn/img/champion/splash/{callback.data}_0.jpg'
    bot.send_photo(callback.message.chat.id, link)
    
    template = r'(<p data-testid="overview:description">)(.*)(<!--)'
    champ = ''
    if callback.data == 'Lux':
        champ = 'lux'
    elif callback.data == 'Garen':
        champ = 'garen'
    elif callback.data == 'MasterYi':
        champ = 'master-yi'
    link = f'https://www.leagueoflegends.com/ru-ru/champions/{champ}'
    request = requests.get(link)
    description = re.search(template, request.text)[2]
    bot.send_message(callback.message.chat.id, description)
    
bot.polling(non_stop=True)

# %%
import numpy as np
roots = int(input("Введите количество неизвестных: "))
constraint = int(input("Введите количество ограничений: "))

coefficients = [[0] * roots for i in range(constraint)]
sign = [0 for i in range(constraint)]
right = [0 for i in range(constraint)]
functionCoefficients = [0 for i in range(roots)]

for i in range(constraint):
    for j in range(roots):
        coefficients[i][j] = float(input("Введите значение " + str(j + 1)
                                       + " коэффициента " + str(i + 1) + " ограничения: "))
for i in range(constraint):
    sign[i] = input("Введите знак равенства / неравенства ограничений: ")
for i in range(constraint):
    right[i] = int(input("Введите правую часть ограничений: "))
for i in range(roots):
    functionCoefficients[i] = float(input("Введите " + str(i + 1) + " коэффициенты фунцкии: "))

constraintInequality = [0 for i in range(0)]
constraintEquality = [o for i in range(0)]
for i in range(constraint):
    if sign[i] != "==":
        constraintInequality.append(i)
    else:
        constraintEquality.append(i)

n = 0
for i in range(len(constraintInequality)):
    for j in range(len(constraintInequality)):
        n = i
        if n == j:
            if sign[constraintInequality[i]] == "<=":
                coefficients[constraintInequality[i]].insert(roots + j, float(1))
                n -= 1
            else:
                coefficients[constraintInequality[i]].insert(roots + j, float(-1))
        else:
            coefficients[constraintInequality[i]].insert(roots + j, float(0))

for i in range(len(constraintEquality)):
    for j in range(len(constraintInequality)):
        coefficients[constraintInequality[i]].insert(roots + j, float(0))

for i in range(roots):
    functionCoefficients[i] *= -1

for i in range(len(constraintInequality) + 1):
    functionCoefficients.append(float(0))

print(np.row_stack([np.column_stack([coefficients, right]), functionCoefficients]))
# Out:
# Введите количество неизвестных: 5
# Введите количество ограничений: 4
# Введите значение 1 коэффициента 1 ограничения: 0.7
# Введите значение 2 коэффициента 1 ограничения: 0.9
# Введите значение 3 коэффициента 1 ограничения: 1.5
# Введите значение 4 коэффициента 1 ограничения: 2.3
# Введите значение 5 коэффициента 1 ограничения: 1.8
# Введите значение 1 коэффициента 2 ограничения: 0.4
# Введите значение 2 коэффициента 2 ограничения: 1.1
# Введите значение 3 коэффициента 2 ограничения: -0.5
# Введите значение 4 коэффициента 2 ограничения: 1.3
# Введите значение 5 коэффициента 2 ограничения: -2.8
# Введите значение 1 коэффициента 3 ограничения: 0.5
# Введите значение 2 коэффициента 3 ограничения: 0
# Введите значение 3 коэффициента 3 ограничения: 1.8
# Введите значение 4 коэффициента 3 ограничения: 0.7
# Введите значение 5 коэффициента 3 ограничения: 2
# Введите значение 1 коэффициента 4 ограничения: 2.2
# Введите значение 2 коэффициента 4 ограничения: -1.4
# ...

# %%
# ?np.row_stack
